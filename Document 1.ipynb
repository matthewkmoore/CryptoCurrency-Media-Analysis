# %% [markdown]
# # Relationship Between On-Line Media Sentiment, Language Usage, and Cryptocurrency Market Capitalization

# %% [markdown]
# ## MA5832 Assessment 3
# ## Matthew Moore
# ## Jc626851
# ## 1379701

# %% [markdown]
# ## Overview
# The following project consists of a proof of concept for defining the effect of specific wordage in online content on crypto currency success when used in varying sentiments.
#
#
# ### The Issue to be solved
# There is a complex two way relationship between financial markets and media references.  This is particularly true in crypto currency markets as opinions are expressed freely, and in high volume irrespective of the authors experience or motives.  While it can be assumed that articles, white papers, analysis, and blog posts will have a relationship with the success or failure of a cryptocurrency (Although not necessarily causal), it is difficult to determine the relationship between the language used, features referenced, and reporting of compelling events on the final success or failure of an alternative currency.  This becomes more confounded when the sentiment of the reporting is taken into effect, is a negative statement about a cryptocurrency containing government references generally associated with a successful or failed currency.
#
# To better understand the relationship between online media reporting, and the overall success of a crypto currency a web scraper and Natural language Processing tsk were set up as shown in Figure 1.
#
# The first component, a web crawler was set up to identify 26 long standing crypto currencies on Wikipedia’s list of crypto currencies page (https://en.wikipedia.org/wiki/List_of_cryptocurrencies).  For each cryptocurrency, the corresponding Wikipedia article was scraped into a corpus of documents.  This corpus was then expanded by scraping all pages from the reference article for each cryptocurrency, provided that the reference article contained the currency name or ticker symbol.  This dataset was chosen as it provided a generalised corpus of documents covering media references, whitepapers, community pages and other sources over a wide time range.  This dataset is enriched with the current market capitalisation for each cryptocurrency provided by the coinmarketcap.com API.
#
# The second component consisted of a Natural language processor.  The NLP component tokenised the documents into individual sentences, before performing sentiment analysis.  The extracted sentences were also lemmatized, and cleansed of any non-word characters to reduce the cardinality of the data set.  The cleansed, and sentiment tagged data was then vectorized, and used to train classification models to predict currency name for word features found in positive, negative and neutral statements, and regression models to predict market capitalisation (success) for word features found in positive, negative, and neutral statements.  These models provided 6 lists of high importance word features for each scenario, this allows comparison of features separating specific currencies, with those predicting outcomes for similarities.  This also allows for the relationship between features, sentiment and ultimate market success to be determined.
# By taking this generalised approach, broad generalisations between online-media sentiment on specific events, features, or opinions and their effect when referenced positively or negatively on final market outcomes can be inferred.

# %% [markdown]
# (Figure 1: Crypto Currency Media Analysis Architecture)
# ![Algorithm%20diagram.PNG](attachment:Algorithm%20diagram.PNG)
